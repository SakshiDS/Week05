# %% [markdown]
# # Assignment - What's the Weather Like?
#
# ## Background
#
# Whether financial, political, or social -- data's true power lies in its ability to answer questions definitively. So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: "What's the weather like as we approach the equator?"
#
# Now, we know what you may be thinking: _"Duh. It gets hotter..."_
#
# But, if pressed, how would you **provide evidence**?
#
# ## WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * OPTIONAL: Include a print log of each city as it's being processed with the city number and city name.
# * OPTIONAL: Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib ,Seaborn or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
#
# ## Hints and Considerations
#
# * The city data is generated based on random coordinates; as such, your outputs will not be an exact match to the provided starter notebook.
#
# * You may want to start this assignment by refreshing yourself on the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).
#
# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# * A starter code for Citipy has been provided. However, if you're craving an extra challenge, push yourself to learn how it works: [citipy Python library](https://pypi.python.org/pypi/citipy).
#
# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Don't modify this cell.
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Don't modify this cell
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# A lot of starter code has been generated for you. Use the cell below to play with the data to ensure you know what's happening.

# %%
# Checking for last few cities name
cities[620:625]
# Out:
# ['sabha', 'bargal', 'saint-georges', 'lukiv', 'sao filipe']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city in `cities` using a series of successive API calls. Think: how do you do anything successively?
# * Make sure each city in your dataset includes coordinates, country, max temperature, pressure, humidity and wind speed
# * Use a try-except to handle errors (they will occur)
# * Include a print log of each city as it'sbeing processed (with the city number and city name). City number is just going to count which city is being processed

# %%
# Initializing dictionary to take save city weather data
city_weather = {'City':[],
                'Date':[],
                'Country':[],
                'Cloudiness':[],
                'Max_temp':[],
               'Pressure':[],
               'Humidity':[],
                'lng':[],
                'lat':[],
               'wind_speed':[]}

city_num = 0

# %%
# Looping through list of cities to fetch weather data for each one of them
for city in cities:
    base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
    try:
        req = requests.get(base_url + f'&q={city}')
        data = req.json()
        city_weather['City'].append(data['name'])
        city_weather['Date'].append(data['dt'])
        city_weather['Country'].append(data['sys']['country'])
        city_weather['Cloudiness'].append(data['clouds']['all'])
        city_weather['Max_temp'].append(data['main']['temp_max'])
        city_weather['Pressure'].append(data['main']['pressure'])
        city_weather['Humidity'].append(data['main']['humidity'])
        city_weather['lng'].append(data['coord']['lon'])
        city_weather['lat'].append(data['coord']['lat'])
        city_weather['wind_speed'].append(data['wind']['speed'])
        city_num += 1
        print("Processing..  City Number: ",city_num," City Name: ",city)
    except:
        print(city+ " not found")
        pass
# Out:
# Processing..  City Number:  1  City Name:  chara
# galiwinku not found
# Processing..  City Number:  2  City Name:  bilibino
# Processing..  City Number:  3  City Name:  saint-philippe
# Processing..  City Number:  4  City Name:  avarua
# alotau not found
# Processing..  City Number:  5  City Name:  carnarvon
# Processing..  City Number:  6  City Name:  tuktoyaktuk
# Processing..  City Number:  7  City Name:  nikolskoye
# Processing..  City Number:  8  City Name:  hobart
# Processing..  City Number:  9  City Name:  ushuaia
# Processing..  City Number:  10  City Name:  otradnoye
# sentyabrskiy not found
# Processing..  City Number:  11  City Name:  qaanaaq
# Processing..  City Number:  12  City Name:  padang
# Processing..  City Number:  13  City Name:  liseleje
# Processing..  City Number:  14  City Name:  barrow
# Processing..  City Number:  15  City Name:  mataura
# Processing..  City Number:  16  City Name:  castro
# Processing..  City Number:  17  City Name:  saskylakh
# Processing..  City Number:  18  City Name:  san patricio
# Processing..  City Number:  19  City Name:  mahebourg
# Processing..  City Number:  20  City Name:  albany
# Processing..  City Number:  21  City Name:  vaini
# Processing..  City Number:  22  City Name:  longyearbyen
# Processing..  City Number:  23  City Name:  ozernovskiy
# Processing..  City Number:  24  City Name:  airai
# Processing..  City Number:  25  City Name:  hithadhoo
# Processing..  City Number:  26  City Name:  urubicha
# Processing..  City Number:  27  City Name:  ambon
# Processing..  City Number:  28  City Name:  punta arenas
# Processing..  City Number:  29  City Name:  qasigiannguit
# Processing..  City Number:  30  City Name:  lebu
# bajo baudo not found
# tsihombe not found
# palabuhanratu not found
# Processing..  City Number:  31  City Name:  pilar
# Processing..  City Number:  32  City Name:  terra santa
# Processing..  City Number:  33  City Name:  hilo
# Processing..  City Number:  34  City Name:  weihai
# Processing..  City Number:  35  City Name:  vila velha
# Processing..  City Number:  36  City Name:  oranjemund
# Processing..  City Number:  37  City Name:  pilot butte
# Processing..  City Number:  38  City Name:  kapaa
# Processing..  City Number:  39  City Name:  kavieng
# Processing..  City Number:  40  City Name:  mweka
# Processing..  City Number:  41  City Name:  sao joaquim do monte
# Processing..  City Number:  42  City Name:  busselton
# Processing..  City Number:  43  City Name:  east london
# Processing..  City Number:  44  City Name:  constitucion
# Processing..  City Number:  45  City Name:  yelyzavethradka
# Processing..  City Number:  46  City Name:  port elizabeth
# Processing..  City Number:  47  City Name:  turan
# Processing..  City Number:  48  City Name:  avera
# Processing..  City Number:  49  City Name:  atar
# Processing..  City Number:  50  City Name:  bandarbeyla
# taolanaro not found
# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Display the DataFrame
# * Export the city data into a .csv. Open it up in excel or another program to make sure it looks as expected

# %%
# Saving the data to Pandas DataFrame
city_weather_df = pd.DataFrame(city_weather)

city_weather_df["Date"] = pd.to_datetime(city_weather_df['Date'], unit='s')

city_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        574 non-null    object
#  1   Date        574 non-null    datetime64[ns]
#  2   Country     574 non-null    object
#  3   Cloudiness  574 non-null    int64
#  4   Max_temp    574 non-null    float64
#  5   Pressure    574 non-null    int64
#  6   Humidity    574 non-null    int64
#  7   lng         574 non-null    float64
#  8   lat         574 non-null    float64
#  9   wind_speed  574 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(2)
# memory usage: 45.0+ KB

# %%
city_weather_df.head()
# Out:
#              City                Date Country  Cloudiness  Max_temp  Pressure  \
# 0           Chara 2021-10-20 22:14:58      RU          67     26.02      1025
# 1        Bilibino 2021-10-20 22:14:58      RU         100      0.59      1011
# 2  Saint-Philippe 2021-10-20 22:14:59      RE          42     71.19      1019
# 3          Avarua 2021-10-20 22:11:18      CK          75     77.05      1017
# 4       Carnarvon 2021-10-20 22:14:59      AU          90     64.47      1018
#
#    Humidity       lng      lat  wind_speed
# 0        77  118.2631  56.9064        3.53
# 1        96  166.4372  68.0546        2.33
# 2        79   55.7679 -21.3585       10.96
# 3        65 -159.7750 -21.2078        6.91
# 4        72  113.6333 -24.8667        5.75

# %%
# Saving data to csv file
city_weather_df.to_csv("City_Weather.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Use matplotlib
# * Save the plotted figures as .pngs and embed those pngs in your readme file.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.style.use("seaborn-whitegrid")
plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"]  = 1.25
today = pd.to_datetime("today")
today = today.strftime("%d/%m/%Y")


fig0, ax0 = plt.subplots()
ax0.scatter(city_weather_df["lat"],city_weather_df["Max_temp"],alpha=0.8, color='tab:blue', edgecolor='black')
ax0.set_xlabel("Latitude")
ax0.set_ylabel("Max Temperature (F)")
ax0.set_title("City Latitude vs. Max Temperature ({date})".format(date=today))

plt.savefig("latvstemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig1, ax1 = plt.subplots()
ax1.scatter(city_weather_df["lat"],city_weather_df["Humidity"],alpha=0.8, color='tab:blue', edgecolor='black')
ax1.set_xlabel("Latitude")
ax1.set_ylabel("Humidity (%)")
ax1.set_title("City Latitude vs. Humidity ({date})".format(date=today))

plt.savefig("latvshumidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig2, ax2 = plt.subplots()
ax2.scatter(city_weather_df["lat"],city_weather_df["Cloudiness"],alpha=0.8, color='tab:blue', edgecolor='black')
ax2.set_xlabel("Latitude")
ax2.set_ylabel("Cloudiness (%)")
ax2.set_title("City Latitude vs. Cloudiness ({date})".format(date=today))

plt.savefig("latvscloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig3, ax3 = plt.subplots()
ax3.scatter(city_weather_df["lat"],city_weather_df["wind_speed"],alpha=0.8, color='tab:blue', edgecolor='black')
ax3.set_xlabel("Latitude")
ax3.set_ylabel("Wind Speed (mph)")
ax3.set_title("City Latitude vs. Wind Speed ({date})".format(date=today))

plt.savefig("latvswindspeed.png")
plt.show()

# %% [markdown]
# ### Use the Seaborn library to re-create 2-4 of the above plots.
# * Use the same data just make a different plot.
# * Note the differences in amount of code required to generate a similar plot.

# %%
import seaborn as sns


        
sns.set_style("whitegrid")
sns.set_palette("PRGn")
sns.set_context("talk")

# %% [markdown]
# #### Latitude vs. Humidity/Cloudiness/Wind Speed Plot

# %%
g = sns.relplot(x="lat",y="Humidity",data=city_weather_df,kind="scatter",palette="PuRd",size="Cloudiness",hue="wind_speed",height=7,edgecolor="black")
g.fig.suptitle("Latitude vs Humidity(%) / Cloudiness(%) / Wind Speed(mph) ({date})".format(date=today), y=1.05)
g.set(xlabel="Latitude",ylabel="Humidity (%)")


plt.savefig("seaborn_plot.png")        
plt.show()

# %% [markdown]
# ### As a Data-Scientist:
# In addition to generating data, munging data and plotting data you will also be responsible for *interpreting* data.
# * Provide a written description of three observable trends based on the data.

# %% [markdown]
# #### Observations:
#     1. Max Temperatures peak near the equator and dip near the pole.
#     2. Wind Speed is higher in places with high humidity.
#     3. Cloudiness is observed across cities irrespective of the coordinate location.

# %% [markdown]
# ### OPTIONAL Homework Problem:
# * Use a **different** api endpoint such as `Hourly Forecast 4 days` to get data.
# * Other weather api endpoints are documented [here](https://openweathermap.org/api).
# * You will have to change the URL parameters to get the data you want.
# * Get the data into a data structure of your choice. (Pandas, dicts, lists etc...)
# * Use the plotting library of your choice to make 1-4 plots of your choice.

# %%
base_url = "http://api.openweathermap.org/data/2.5/forecast?units=Imperial&APPID=" + api_key
city = 'chesterfield'

#q represents the city
req = requests.get(base_url + f'&q={city}')
data=req.json()

# %%
forecast = data['list']
forecast_df = pd.DataFrame(forecast)
forecast_df["dt"] = pd.to_datetime(forecast_df['dt'], unit='s')
forecast_df = forecast_df.set_index("dt")
forecast_df.head()
# Out:
#                                                                   main  \
# dt
# 2021-10-20 18:00:00  {'temp': 73.45, 'feels_like': 72.66, 'temp_min...
# 2021-10-20 21:00:00  {'temp': 73.9, 'feels_like': 72.97, 'temp_min'...
# 2021-10-21 00:00:00  {'temp': 65.73, 'feels_like': 64.4, 'temp_min'...
# 2021-10-21 03:00:00  {'temp': 58.26, 'feels_like': 56.37, 'temp_min...
# 2021-10-21 06:00:00  {'temp': 56.21, 'feels_like': 53.98, 'temp_min...
#
#                                                                weather  \
# dt
# 2021-10-20 18:00:00  [{'id': 801, 'main': 'Clouds', 'description': ...
# 2021-10-20 21:00:00  [{'id': 800, 'main': 'Clear', 'description': '...
# 2021-10-21 00:00:00  [{'id': 800, 'main': 'Clear', 'description': '...
# 2021-10-21 03:00:00  [{'id': 800, 'main': 'Clear', 'description': '...
# 2021-10-21 06:00:00  [{'id': 800, 'main': 'Clear', 'description': '...
#
#                           clouds                                       wind  \
# dt
# 2021-10-20 18:00:00  {'all': 11}  {'speed': 4.92, 'deg': 216, 'gust': 6.58}
# 2021-10-20 21:00:00   {'all': 7}  {'speed': 4.21, 'deg': 216, 'gust': 7.07}
# 2021-10-21 00:00:00   {'all': 4}  {'speed': 4.94, 'deg': 199, 'gust': 6.87}
# 2021-10-21 03:00:00   {'all': 0}  {'speed': 5.35, 'deg': 206, 'gust': 10.2}
# 2021-10-21 06:00:00   {'all': 4}  {'speed': 5.21, 'deg': 220, 'gust': 13.6}
#
#                      visibility  pop           sys               dt_txt
# dt
# 2021-10-20 18:00:00       10000  0.0  {'pod': 'd'}  2021-10-20 18:00:00
# 2021-10-20 21:00:00       10000  0.0  {'pod': 'd'}  2021-10-20 21:00:00
# 2021-10-21 00:00:00       10000  0.0  {'pod': 'n'}  2021-10-21 00:00:00
# 2021-10-21 03:00:00       10000  0.0  {'pod': 'n'}  2021-10-21 03:00:00
# 2021-10-21 06:00:00       10000  0.0  {'pod': 'n'}  2021-10-21 06:00:00

# %%
forecast_main = {'temp':[],
                'feels_like':[],
                'temp_min':[],
                'temp_max':[],
                'pressure':[],
                'humidity':[]}

for i in forecast_df["main"]:
    try:
        forecast_main['temp'].append(i['temp'])
        forecast_main['feels_like'].append(i['feels_like'])
        forecast_main['temp_min'].append(i['temp_min'])
        forecast_main['temp_max'].append(i['temp_max'])
        forecast_main['pressure'].append(i['pressure'])
        forecast_main['humidity'].append(i['humidity'])
    except:
        print("error encountered")

# %%
forecast_main_df = pd.DataFrame(forecast_main)
forecast_main_df["Date"] = forecast_df.index
forecast_main_df = forecast_main_df.set_index("Date")
forecast_main_df.head()
# Out:
#                       temp  feels_like  temp_min  temp_max  pressure  humidity
# Date
# 2021-10-20 18:00:00  73.45       72.66     73.45     76.33      1023        46
# 2021-10-20 21:00:00  73.90       72.97     73.90     74.82      1022        42
# 2021-10-21 00:00:00  65.73       64.40     61.88     65.73      1021        51
# 2021-10-21 03:00:00  58.26       56.37     58.26     58.26      1020        55
# 2021-10-21 06:00:00  56.21       53.98     56.21     56.21      1019        52

# %%
forecast_main_df['Date']= forecast_main_df.index.date
forecast_main_df['Time'] = forecast_main_df.index.time

# %%
forecast_main_df.head()
# Out:
#                       temp  feels_like  temp_min  temp_max  pressure  \
# Date
# 2021-10-20 18:00:00  73.45       72.66     73.45     76.33      1023
# 2021-10-20 21:00:00  73.90       72.97     73.90     74.82      1022
# 2021-10-21 00:00:00  65.73       64.40     61.88     65.73      1021
# 2021-10-21 03:00:00  58.26       56.37     58.26     58.26      1020
# 2021-10-21 06:00:00  56.21       53.98     56.21     56.21      1019
#
#                      humidity        Date      Time
# Date
# 2021-10-20 18:00:00        46  2021-10-20  18:00:00
# 2021-10-20 21:00:00        42  2021-10-20  21:00:00
# 2021-10-21 00:00:00        51  2021-10-21  00:00:00
# 2021-10-21 03:00:00        55  2021-10-21  03:00:00
# 2021-10-21 06:00:00        52  2021-10-21  06:00:00

# %% [markdown]
# ### Temperature variation over next 5 days in Chesterfield
# Work in Progress...

# %%
fig4, ax4 = plt.subplots()
ax4.plot(forecast_main_df.index,forecast_main_df["temp"],forecast_main_df['temp_min'])
ax4.tick_params('x',rotation=90)

plt.show()

# %% [markdown]
# ## Introduction to data visualization with Matplotlib

# %% [markdown]
# ![Into%20to%20Data%20Viz%20with%20Matplotlib.PNG](attachment:Into%20to%20Data%20Viz%20with%20Matplotlib.PNG)

# %% [markdown]
# ## Introduction to data visualization with Seaborn

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)
